# %% [markdown]
# ## Python Mini-Project: Data Clean-Up, Pt. 1
#
# Pay close attention to the prompts to help guide you through this task.

# %%
# Dependencies
import pandas as pd
import os

# %%
# load CSV
path = os.path.join("Resources/2016-FCC-New-Coders-Survey-Data.csv")
coders_df = pd.read_csv(path)
coders_df.head()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (21,57) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# 1                NaN             NaN  ...               NaN
# 2                NaN             NaN  ...               NaN
# 3                NaN             NaN  ...               NaN
# 4                NaN             NaN  ...               NaN
#
#    ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  ResourceUdemy  \
# 0                    NaN                NaN              NaN            NaN
# 1                    NaN                NaN              NaN            1.0
# 2                    NaN                NaN              NaN            NaN
# 3                    NaN                NaN              NaN            NaN
# 4                    NaN                NaN              NaN            NaN
#
#    ResourceW3Schools  ResourceYouTube  \
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN
#
#                               SchoolDegree              SchoolMajor  \
# 0           some college credit, no degree                      NaN
# 1           some college credit, no degree                      NaN
# 2  high school diploma or equivalent (GED)                      NaN
# 3                        bachelor's degree  Cinematography And Film
# 4           some college credit, no degree                      NaN
#
#    StudentDebtOwe
# 0         20000.0
# 1             NaN
# 2             NaN
# 3          7000.0
# 4             NaN
#
# [5 rows x 113 columns]

# %%
# Read with pandas
coders_df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# 1                NaN             NaN  ...               NaN
# 2                NaN             NaN  ...               NaN
# 3                NaN             NaN  ...               NaN
# 4                NaN             NaN  ...               NaN
#
#    ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  ResourceUdemy  \
# 0                    NaN                NaN              NaN            NaN
# 1                    NaN                NaN              NaN            1.0
# 2                    NaN                NaN              NaN            NaN
# 3                    NaN                NaN              NaN            NaN
# 4                    NaN                NaN              NaN            NaN
#
#    ResourceW3Schools  ResourceYouTube  \
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN
#
#                               SchoolDegree              SchoolMajor  \
# 0           some college credit, no degree                      NaN
# 1           some college credit, no degree                      NaN
# 2  high school diploma or equivalent (GED)                      NaN
# 3                        bachelor's degree  Cinematography And Film
# 4           some college credit, no degree                      NaN
#
#    StudentDebtOwe
# 0         20000.0
# 1             NaN
# 2             NaN
# 3          7000.0
# 4             NaN
#
# [5 rows x 113 columns]

# %%
# Inspect all columns
coders_df.columns
# Out:
# Index(['Age', 'AttendedBootcamp', 'BootcampFinish', 'BootcampFullJobAfter',
#        'BootcampLoanYesNo', 'BootcampMonthsAgo', 'BootcampName',
#        'BootcampPostSalary', 'BootcampRecommend', 'ChildrenNumber',
#        ...
#        'ResourceSoloLearn', 'ResourceStackOverflow', 'ResourceTreehouse',
#        'ResourceUdacity', 'ResourceUdemy', 'ResourceW3Schools',
#        'ResourceYouTube', 'SchoolDegree', 'SchoolMajor', 'StudentDebtOwe'],
#       dtype='object', length=113)

# %%
# Extract only columns 0, 1, 2, 3, 4, 7, 8, 9, 10,11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
# Use iloc to accomplish this (remember that you need to take the position of the rows and columns into account)

coders_df.iloc[:,[0, 1, 2, 3, 4, 7, 8, 9, 10,11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0      28.0               0.0             NaN                   NaN
# 1      22.0               0.0             NaN                   NaN
# 2      19.0               0.0             NaN                   NaN
# 3      26.0               0.0             NaN                   NaN
# 4      20.0               0.0             NaN                   NaN
# ...     ...               ...             ...                   ...
# 15615  39.0               0.0             NaN                   NaN
# 15616  27.0               0.0             NaN                   NaN
# 15617  37.0               0.0             NaN                   NaN
# 15618  26.0               0.0             NaN                   NaN
# 15619  22.0               0.0             NaN                   NaN
#
#        BootcampLoanYesNo  BootcampPostSalary  BootcampRecommend  \
# 0                    NaN                 NaN                NaN
# 1                    NaN                 NaN                NaN
# 2                    NaN                 NaN                NaN
# 3                    NaN                 NaN                NaN
# 4                    NaN                 NaN                NaN
# ...                  ...                 ...                ...
# 15615                NaN                 NaN                NaN
# 15616                NaN                 NaN                NaN
# 15617                NaN                 NaN                NaN
# 15618                NaN                 NaN                NaN
# 15619                NaN                 NaN                NaN
#
#        ChildrenNumber                 CityPopulation  CodeEventBootcamp  \
# 0                 NaN  between 100,000 and 1 million                NaN
# 1                 NaN  between 100,000 and 1 million                NaN
# 2                 NaN            more than 1 million                NaN
# 3                 NaN            more than 1 million                NaN
# 4                 NaN  between 100,000 and 1 million                NaN
# ...               ...                            ...                ...
# 15615             NaN            more than 1 million                NaN
# 15616             NaN            more than 1 million                NaN
# 15617             NaN            more than 1 million                NaN
# 15618             NaN            more than 1 million                NaN
# 15619             NaN            more than 1 million                NaN
#
#                     CountryLive                        EmploymentField  \
# 0      United States of America      office and administrative support
# 1      United States of America                      food and beverage
# 2      United States of America                                finance
# 3      United States of America  arts, entertainment, sports, or media
# 4      United States of America                              education
# ...                         ...                                    ...
# 15615                     Kenya            software development and IT
# 15616                     India            software development and IT
# 15617                   Nigeria                                    NaN
# 15618                     Spain                              education
# 15619  United States of America  arts, entertainment, sports, or media
#
#                EmploymentStatus  Gender  HasChildren  HoursLearning   Income  \
# 0            Employed for wages    male          0.0           30.0  32000.0
# 1            Employed for wages    male          NaN           30.0  15000.0
# 2            Employed for wages    male          NaN           20.0  48000.0
# 3            Employed for wages  female          NaN           20.0  43000.0
# 4            Employed for wages  female          NaN           25.0   6000.0
# ...                         ...     ...          ...            ...      ...
# 15615  Self-employed freelancer    male          0.0           40.0  10000.0
# 15616        Employed for wages    male          0.0           15.0  10000.0
# 15617  Self-employed freelancer    male          NaN           14.0  48000.0
# 15618  Self-employed freelancer    male          NaN           10.0  10000.0
# 15619        Employed for wages  female          0.0            2.0  18000.0
#
#                  JobRoleInterest                             SchoolDegree  \
# 0                            NaN           some college credit, no degree
# 1        Front-End Web Developer           some college credit, no degree
# 2                            NaN  high school diploma or equivalent (GED)
# 3        Front-End Web Developer                        bachelor's degree
# 4       Full-Stack Web Developer           some college credit, no degree
# ...                          ...                                      ...
# 15615                        NaN                        bachelor's degree
# 15616    Front-End Web Developer                        bachelor's degree
# 15617                        NaN                        bachelor's degree
# 15618                        NaN       master's degree (non-professional)
# 15619                        NaN                        bachelor's degree
#
#                    SchoolMajor
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3      Cinematography And Film
# 4                          NaN
# ...                        ...
# 15615                Chemistry
# 15616   Electrical Engineering
# 15617                Chemistry
# 15618                     Math
# 15619           Graphic Design
#
# [15620 rows x 20 columns]

# %%
# Change "0" to "No" and "1" to "Yes" in response columns
converted_df = coders_df.replace([0.0, 1.0,], ["No","Yes"])
# Hint use the df.replace function
converted_df
# Out:
#         Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0      28.0               No            NaN                  NaN
# 1      22.0               No            NaN                  NaN
# 2      19.0               No            NaN                  NaN
# 3      26.0               No            NaN                  NaN
# 4      20.0               No            NaN                  NaN
# ...     ...              ...            ...                  ...
# 15615  39.0               No            NaN                  NaN
# 15616  27.0               No            NaN                  NaN
# 15617  37.0               No            NaN                  NaN
# 15618  26.0               No            NaN                  NaN
# 15619  22.0               No            NaN                  NaN
#
#       BootcampLoanYesNo BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                   NaN               NaN          NaN                 NaN
# 1                   NaN               NaN          NaN                 NaN
# 2                   NaN               NaN          NaN                 NaN
# 3                   NaN               NaN          NaN                 NaN
# 4                   NaN               NaN          NaN                 NaN
# ...                 ...               ...          ...                 ...
# 15615               NaN               NaN          NaN                 NaN
# 15616               NaN               NaN          NaN                 NaN
# 15617               NaN               NaN          NaN                 NaN
# 15618               NaN               NaN          NaN                 NaN
# 15619               NaN               NaN          NaN                 NaN
#
#       BootcampRecommend ChildrenNumber  ... ResourceSoloLearn  \
# 0                   NaN            NaN  ...               NaN
# 1                   NaN            NaN  ...               NaN
# 2                   NaN            NaN  ...               NaN
# 3                   NaN            NaN  ...               NaN
# 4                   NaN            NaN  ...               NaN
# ...                 ...            ...  ...               ...
# 15615               NaN            NaN  ...               NaN
# 15616               NaN            NaN  ...               NaN
# 15617               NaN            NaN  ...               NaN
# 15618               NaN            NaN  ...               NaN
# 15619               NaN            NaN  ...               NaN
#
#       ResourceStackOverflow ResourceTreehouse ResourceUdacity ResourceUdemy  \
# 0                       NaN               NaN             NaN           NaN
# 1                       NaN               NaN             NaN           Yes
# 2                       NaN               NaN             NaN           NaN
# 3                       NaN               NaN             NaN           NaN
# 4                       NaN               NaN             NaN           NaN
# ...                     ...               ...             ...           ...
# 15615                   NaN               NaN             NaN           Yes
# 15616                   NaN               Yes             NaN           NaN
# 15617                   NaN               NaN             NaN           NaN
# 15618                   NaN               NaN             NaN           Yes
# 15619                   NaN               NaN             NaN           NaN
#
#       ResourceW3Schools ResourceYouTube  \
# 0                   NaN             NaN
# 1                   NaN             NaN
# 2                   NaN             NaN
# 3                   NaN             NaN
# 4                   NaN             NaN
# ...                 ...             ...
# 15615               NaN             NaN
# 15616               NaN             NaN
# 15617               NaN             NaN
# 15618               NaN             NaN
# 15619               NaN             NaN
#
#                                   SchoolDegree              SchoolMajor  \
# 0               some college credit, no degree                      NaN
# 1               some college credit, no degree                      NaN
# 2      high school diploma or equivalent (GED)                      NaN
# 3                            bachelor's degree  Cinematography And Film
# 4               some college credit, no degree                      NaN
# ...                                        ...                      ...
# 15615                        bachelor's degree                Chemistry
# 15616                        bachelor's degree   Electrical Engineering
# 15617                        bachelor's degree                Chemistry
# 15618       master's degree (non-professional)                     Math
# 15619                        bachelor's degree           Graphic Design
#
#       StudentDebtOwe
# 0              20000
# 1                NaN
# 2                NaN
# 3               7000
# 4                NaN
# ...              ...
# 15615            NaN
# 15616            NaN
# 15617            NaN
# 15618            NaN
# 15619          40000
#
# [15620 rows x 113 columns]

# %%
# Calculate total number of respondents in survey
len(converted_df)
# consider using the len() function
# Out:
# 15620

# %%
# Extract rows corresponding only to people who attended a bootcamp
attended_df = converted_df.loc[converted_df["AttendedBootcamp"] == "Yes"]
attended_df.tail()
# Filter using df.loc on the AttendedBootcamp column
# Out:
#         Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 15539  39.0              Yes            Yes                  Yes
# 15540  24.0              Yes            Yes                  Yes
# 15541  23.0              Yes            Yes                  Yes
# 15593  29.0              Yes             No                  NaN
# 15600  28.0              Yes            Yes                  Yes
#
#       BootcampLoanYesNo BootcampMonthsAgo              BootcampName  \
# 15539               Yes               Yes                 CodeaCamp
# 15540               Yes                12  Anyone Can Learn To Code
# 15541                No                 8                 CodeaCamp
# 15593                No               NaN            Camp Code Away
# 15600                No                 4                  Epicodus
#
#        BootcampPostSalary BootcampRecommend ChildrenNumber  ...  \
# 15539                 NaN               Yes            NaN  ...
# 15540                 NaN                No            NaN  ...
# 15541             21600.0               Yes            NaN  ...
# 15593                 NaN                No            NaN  ...
# 15600             36000.0               Yes            NaN  ...
#
#       ResourceSoloLearn ResourceStackOverflow ResourceTreehouse  \
# 15539               NaN                   NaN               NaN
# 15540               NaN                   NaN               NaN
# 15541               NaN                   NaN               NaN
# 15593               NaN                   NaN               NaN
# 15600               NaN                   NaN               NaN
#
#       ResourceUdacity ResourceUdemy ResourceW3Schools ResourceYouTube  \
# 15539             NaN           NaN               NaN             NaN
# 15540             NaN           NaN               NaN             NaN
# 15541             NaN           NaN               NaN             NaN
# 15593             NaN           NaN               NaN             NaN
# 15600             NaN           NaN               NaN             NaN
#
#                              SchoolDegree  \
# 15539      some college credit, no degree
# 15540                   bachelor's degree
# 15541  master's degree (non-professional)
# 15593                   bachelor's degree
# 15600                   bachelor's degree
#
#                                              SchoolMajor StudentDebtOwe
# 15539                                                NaN            NaN
# 15540  Computer Systems Networking and Telecommunicat...           2500
# 15541                      Computer Software Engineering            NaN
# 15593                                         Accounting            NaN
# 15600                                          Marketing            NaN
#
# [5 rows x 113 columns]

# %%
# Calculate average age of attendees
attended_df['Age']
# Pull out the `Age` series and take the average of it
attended_df['Age'].mean()
# Out:
# 31.066014669926652

# %%
# Calculate how many people attended a bootcamp
len(attended_df)
# Count the values of the AttendedBootcamp column
x = attended_df["AttendedBootcamp"].value_counts()
pd.DataFrame(x)
# Out:
#      AttendedBootcamp
# Yes               953

# %%
# Calculate how many attendees hold degrees
y = attended_df["SchoolDegree"].value_counts()
# It is easier to do this with `value_counts() count values for the SchoolDegree column
y
# Out:
# bachelor's degree                           462
# some college credit, no degree              116
# master's degree (non-professional)           96
# professional degree (MBA, MD, JD, etc.)      39
# high school diploma or equivalent (GED)      38
# associate's degree                           32
# trade, technical, or vocational training     24
# some high school                             10
# Ph.D.                                         8
# no high school (secondary school)             7
# Name: SchoolDegree, dtype: int64

# %%
# Count the number of records where the person is a degree holder
deg_df = attended_df.replace(["bachelor's degree","Ph.D.", "master's degree (non-professional)","professional degree (MBA, MD, JD, etc.)","associate's degree"], ["Yes","Yes","Yes","Yes","Yes"])
deg_df.head()
# There are several ways to approach this. You can look for people who have degrees
# or for people who don't have degrees depending on the value of the SchoolDegree column
# Out:
#       Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 93   32.0              Yes            Yes                   No
# 97   26.0              Yes            Yes                  Yes
# 130  41.0              Yes            Yes                  Yes
# 159  26.0              Yes            Yes                   No
# 188  24.0              Yes             No                  NaN
#
#     BootcampLoanYesNo BootcampMonthsAgo      BootcampName  BootcampPostSalary  \
# 93                 No                 8    Codify Academy                 NaN
# 97                 No                 3    DaVinci Coders             45000.0
# 130               Yes                11     Coder Foundry             75000.0
# 159                No                12  General Assembly                 NaN
# 188               Yes               NaN               NaN                 NaN
#
#     BootcampRecommend ChildrenNumber  ... ResourceSoloLearn  \
# 93                 No            NaN  ...               NaN
# 97                 No            NaN  ...               NaN
# 130               Yes              3  ...               NaN
# 159                No            NaN  ...               NaN
# 188                No            NaN  ...               NaN
#
#     ResourceStackOverflow ResourceTreehouse ResourceUdacity ResourceUdemy  \
# 93                    NaN               NaN             Yes           NaN
# 97                    NaN               NaN             NaN           Yes
# 130                   NaN               NaN             NaN           Yes
# 159                   NaN               NaN             NaN           NaN
# 188                   NaN               Yes             NaN           NaN
#
#     ResourceW3Schools ResourceYouTube                    SchoolDegree  \
# 93                NaN             NaN                             Yes
# 97                NaN             NaN                             Yes
# 130               NaN             NaN  some college credit, no degree
# 159               NaN             NaN  some college credit, no degree
# 188               NaN             NaN  some college credit, no degree
#
#     SchoolMajor StudentDebtOwe
# 93      Biology            NaN
# 97        Music        80000.0
# 130         NaN         8000.0
# 159         NaN            NaN
# 188         NaN            NaN
#
# [5 rows x 113 columns]

# %%
b_df = deg_df.loc[deg_df['SchoolDegree'] == 'Yes']
b_df['SchoolDegree'].count()
# Out:
# 637

# %%
# Count number of attendees who self-identify as male; female; or are of non-binary gender identification
attended_df['Gender'].value_counts()
#len(attended_df['Gender'])
# Out:
# male           496
# female         326
# genderqueer      6
# trans            3
# agender          2
# Name: Gender, dtype: int64

# %%
# Calculate percentage of respondents who attended a bootcamp
bootcamp_avg = len(attended_df) / len(coders_df) 
bootcamp_avg
# Out:
# 0.061011523687580026

# %%
# Calculate percentage of respondents belonging to each gender
percentages = attended_df['Gender'].value_counts('female')
#len(attended_df['Gender'])
percentages
# Out:
# male           0.595438
# female         0.391357
# genderqueer    0.007203
# trans          0.003601
# agender        0.002401
# Name: Gender, dtype: float64

# %%
male = percentages[0]
female = percentages[1]
queer = percentages[2]
trans = percentages[3]
agender = percentages[4]
non = queer + trans + agender
non
# Out:
# 0.013205282112845138

# %%
# Calculate percentage of attendees with a college degree
percent_w_degrees = b_df['SchoolDegree'].count() / len(attended_df)
percent_w_degrees
# Out:
# 0.6684155299055614

# %%
# Calculate average post-bootcamp salary
salary = attended_df['BootcampPostSalary'].mean()
salary
# Out:
# 63740.50606060606

# %%
# Create a new table consolidating above calculations
final_bootcamp = pd.DataFrame({
    "Total Surveyed":[len(converted_df)], "Total Bootcamp Attendees":[len(attended_df)], "% Attended Bootcamp":[bootcamp_avg], "Average Age":[attended_df['Age'].mean()],"Has a Degree":[b_df['SchoolDegree'].count()], "% Male": [male],
"% Female":[female], "% Non Gender Specific": [non], "Average Post Bootcamp Salary": [salary] })

final_bootcamp
# Out:
#    Total Surveyed  Total Bootcamp Attendees  % Attended Bootcamp  Average Age  \
# 0           15620                       953             0.061012    31.066015
#
#    Has a Degree    % Male  % Female  % Non Gender Specific  \
# 0           637  0.595438  0.391357               0.013205
#
#    Average Post Bootcamp Salary
# 0                  63740.506061

# %%
# Improve formatting before outputting spreadsheet
final_formatted = final_bootcamp.style.format({"Total Surveyed": "{:2,}", "% Attended Bootcamp": "{:,.2%}" , "Average Age":"{:.0f}", "% Male":"{:,.2%}","% Female":"{:,.2%}", "% Non Gender Specific":"{:,.2%}", "Average Post Bootcamp Salary":"{:,.2f}"})
final_formatted
# Out:
# <style  type="text/css" >
# </style><table id="T_95ceb41c_867b_11ea_8da2_a683e7aa9aa2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Surveyed</th>        <th class="col_heading level0 col1" >Total Bootcamp Attendees</th>        <th class="col_heading level0 col2" >% Attended Bootcamp</th>        <th class="col_heading level0 col3" >Average Age</th>        <th class="col_heading level0 col4" >Has a Degree</th>        <th class="col_heading level0 col5" >% Male</th>        <th class="col_heading level0 col6" >% Female</th>        <th class="col_heading level0 col7" >% Non Gender Specific</th>        <th class="col_heading level0 col8" >Average Post Bootcamp Salary</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_95ceb41c_867b_11ea_8da2_a683e7aa9aa2level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_95ceb41c_867b_11ea_8da2_a683e7aa9aa2row0_col0" class="data row0 col0" >15,620</td>
#                         <td id="T_95ceb41c_867b_11ea_8da2_a683e7aa9aa2row0_col1" class="data row0 col1" >953</td>
#                         <td id="T_95ceb41c_867b_11ea_8da2_a683e7aa9aa2row0_col2" class="data row0 col2" >6.10%</td>
#                         <td id="T_95ceb41c_867b_11ea_8da2_a683e7aa9aa2row0_col3" class="data row0 col3" >31</td>
#                         <td id="T_95ceb41c_867b_11ea_8da2_a683e7aa9aa2row0_col4" class="data row0 col4" >637</td>
#                         <td id="T_95ceb41c_867b_11ea_8da2_a683e7aa9aa2row0_col5" class="data row0 col5" >59.54%</td>
#                         <td id="T_95ceb41c_867b_11ea_8da2_a683e7aa9aa2row0_col6" class="data row0 col6" >39.14%</td>
#                         <td id="T_95ceb41c_867b_11ea_8da2_a683e7aa9aa2row0_col7" class="data row0 col7" >1.32%</td>
#                         <td id="T_95ceb41c_867b_11ea_8da2_a683e7aa9aa2row0_col8" class="data row0 col8" >63,740.51</td>
#             </tr>
#     </tbody></table>

# %%
# Export to Excel
# Use df.to_excel to export to excel. Don't include the indexes
final_formatted.to_excel('data_cleanup_output_KW.xlsx', index = False)
